# %%
test_dir=r'C:\Users\Divya Nitheyan\Downloads\Fertilizers_Recommendation\DatasetPlantDisease\fruit-dataset\fruit-dataset\test'

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = tf.keras.models.load_model(r'C:\Users\Divya Nitheyan\fruitdata.h5')

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 1686 images belonging to 6 classes.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(r"C:\Users\Divya Nitheyan\Downloads\Fertilizers_Recommendation\DatasetPlantDisease\fruit-dataset\fruit-dataset\train\Corn_(maize)___Northern_Leaf_Blight\13bd65f1-fbdc-4863-9550-51a1bdb4afe7___RS_NLB 3707.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x21927D95160>

# %%
x=image.img_to_array(img)

# %%
x
# Out:
# array([[[152., 143., 160.],
#         [152., 143., 160.],
#         [154., 145., 162.],
#         ...,
#         [122., 117., 124.],
#         [121., 116., 123.],
#         [121., 116., 123.]],
#
#        [[153., 144., 161.],
#         [154., 145., 162.],
#         [154., 145., 162.],
#         ...,
#         [121., 116., 123.],
#         [120., 115., 122.],
#         [119., 114., 121.]],
#
#        [[156., 147., 164.],
#         [155., 146., 163.],
#         [154., 145., 162.],
#         ...,
#         [120., 115., 122.],
#         [119., 114., 121.],
#         [118., 113., 120.]],
#
#        ...,
#
#        [[123., 144., 135.],
#         [122., 143., 134.],
#         [125., 146., 137.],
#         ...,
#         [113., 108., 115.],
#         [114., 109., 116.],
#         [114., 109., 116.]],
#
#        [[129., 150., 141.],
#         [124., 146., 134.],
#         [123., 145., 133.],
#         ...,
#         [112., 107., 114.],
#         [113., 108., 115.],
# ...

# %%
img=image.load_img(r"C:\Users\Divya Nitheyan\Downloads\Fertilizers_Recommendation\DatasetPlantDisease\fruit-dataset\fruit-dataset\test\Corn_(maize)___Northern_Leaf_Blight\0b8d588c-325b-4995-b7ba-4cf2b09b5cba___RS_NLB 3617.jpg",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']
index[y[0]]
# Out:
# 1/1 [==============================] - 0s 74ms/step
# 'Peach___Bacterial_spot'
